# %%
import math

# %% [markdown]
# The safe has a dial with only an arrow on it; around the dial are the numbers `0` through `99` in order. As you turn the dial, it makes a small _click_ noise as it reaches each number.

# %%
dial = range(100) # 0-99

def to_base_100(n):
    if n == 0:
        return "0"
    return n % 100

# %% [markdown]
# The dial starts by pointing at `50`.

# %%
current_dial_position = 50 # starts at 50

# %% [markdown]
# You could follow the instructions, but your recent required official North Pole secret entrance security training seminar taught you that the safe is actually a decoy. The actual password is the number of times the dial is left pointing at 0 after any rotation in the sequence.

# %%
count_times_at_zero = 0 # none at start

def split_direction_from_number(move):
    direction = move[:1]
    number = move[1:]
    return direction, int(number)


def move(direction, number):
    global current_dial_position
    global current_dial_position
    global count_times_at_zero
    global dial
    
    if direction == "L":
        current_dial_position = current_dial_position - number
    if direction == "R":
        current_dial_position = current_dial_position + number

    current_dial_position = int(to_base_100(current_dial_position))

    if current_dial_position == 0:
        count_times_at_zero += 1

# move("L", 100)
# print(current_dial_position, count_times_at_zero)

# move("R", 50)
# print(current_dial_position, count_times_at_zero)

with open("input.txt") as f:
  lines = f.readlines()
  for line in lines:
    # print(split_direction_from_number(line.strip()))
    move(*split_direction_from_number(line.strip()))

print(count_times_at_zero)
# Out:
# 1177
